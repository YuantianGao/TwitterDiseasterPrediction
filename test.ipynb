# %%
import numpy as np
x = np.random.uniform(-1, 1, 10000000)
Z = np.random.normal(5, 3, 10000000)
Y = 2 * x + Z
x = x.reshape(-1, 1)
Y = Y.reshape(-1, 1)
print(x.shape, Y.shape)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x, Y)
# Out:
# (10000000, 1) (10000000, 1)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# import numpy as np
# x = np.random.normal(5, 2, 100)
# Z = np.random.normal(5, 3, 100)
# Y = x + 0.5 * Z
# x = x.reshape(-1, 1)
# Y = Y.reshape(-1, 1)
# print(x.shape, Y.shape)
# from sklearn.linear_model import LinearRegression
# regressor = LinearRegression()
# regressor.fit(x, Y)
# Out:
# (100, 1) (100, 1)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [4.99920218]
# [[2.00280218]]

# %%
w = np.array([-0.01, 0.01])
x = np.array([36, 10])
y = 1 / (1 + np.exp(-(0.1 + np.dot(w, x))))
print(y)
# Out:
# 0.46008511544443426

# %%
import networkx as nx
import matplotlib.pyplot as plt
import networkx.algorithms.centrality as c
G = nx.Graph()

G.add_edges_from([(1, 2), (2, 3), (1,3), (1,4), (1,5), (1,6), (5, 6), (5, 7), (7, 8)])


plt.subplot()
nx.draw(G, with_labels=True, font_weight='bold')

print(c.closeness_centrality(G))
print(c.betweenness_centrality(G))
# Out:
# {1: 0.7, 2: 0.4666666666666667, 3: 0.4666666666666667, 4: 0.4375, 5: 0.6363636363636364, 6: 0.5384615384615384, 7: 0.4666666666666667, 8: 0.3333333333333333}
# {1: 0.6666666666666666, 2: 0.0, 3: 0.0, 4: 0.0, 5: 0.47619047619047616, 6: 0.0, 7: 0.2857142857142857, 8: 0.0}

# %%
import numpy as np
import sklearn.metrics.pairwise as K
import scipy.stats as S
X = np.array([[7, 6, 2, 4.5], [5, 4, 7, 8],])
print(X.shape)
print(X[0].shape)
print(X[1].shape)
print(S.pearsonr(X[0], X[1]))
# Out:
# (2, 3)
# (3,)
# (3,)
# (-0.8170571691028834, 0.3912079900317234)

# %%
w = np.array([1e-7])
x = np.array([11.96e6])
y = 1 / (1 + np.exp(-(1 + np.dot(w, x))))
print(y)
# Out:
# 0.8998897340418424
